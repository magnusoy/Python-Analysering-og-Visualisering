# %% [markdown]
# # Stil og farge
#
# Vi har vist noen få ganger hvordan vi kan kontrollere figurestetikk hos seaborn, men la oss nå gå formelt over det:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')
# Out:
# c:\users\magnus\appdata\local\programs\python\python36\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\magnus\appdata\local\programs\python\python36\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# c:\users\magnus\appdata\local\programs\python\python36\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)
# Namespace(gui='inline', list=False)
# []

# %% [markdown]
# ## Stiler
#
# Du kan angi bestemte stiler:

# %% [markdown]
# ## Fjern bakgrunn

# %% [markdown]
# ## Størrelse og aspekt

# %% [markdown]
# Du kan bruke matplotlibs **plt. Figur (figurstørrelse = (bredde, høyde)** for å endre størrelsen på de fleste sjøfødte tomter.
#
# Du kan kontrollere størrelsen og størrelsesforholdet for de fleste sjøfødte rutenettdiagrammer ved å sende inn parametere: størrelse og aspekt. For eksempel:

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',size=2,aspect=4,data=tips)
# Out:
# c:\users\magnus\appdata\local\programs\python\python36\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Skala og kontekstt
#
# Set_context() lar deg overstyre standardparametere:
